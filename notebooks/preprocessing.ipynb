# %%
import pandas as pd

df= pd.read_excel(r"C:\SKN25-3rd-1Team\data\raw\raw_data.xlsx")

# %%
df.head()
# Out:
#         ID                                   제목            카테고리  \
# 0    39691                 갤럭시, 화면 터치 인식이 안 돼요.   센서/터치 / 소리/진동
# 1    40898              갤럭시, 알람이 설정한 시간에 안 울려요.          애플리케이션
# 2  1847439   갤럭시 AI, 메시지 작성을 도와줄 글쓰기 어시스트 기능 안내   시스템설정 / 전화/문자
# 3  2453371  갤럭시 AI, 크리에이티브 스튜디오(그리기 어시스트) 사용 방법  시스템설정 / 애플리케이션
# 4  1856524                갤럭시 AI, 노트 어시스트 사용 방법  시스템설정 / 애플리케이션
#
#                                                   본문  \
# 0  갤럭시 기기의 화면 터치가 안되거나 간헐적으로 터치 인식이 안되는 현상이 발생하는 ...
# 1  갤럭시 폰 또는 탭 사용 중 알람이 원하는 시간에 울리지 않은 경우에는 일부 설정이...
# 2  메시지를 주고 받을 때 활용할 수 있는 대화 보조 기능을 새롭게 제공합니다. _x0...
# 3  크리에이티브 스튜디오(그리기 어시스트)는 Edge 패널이나 에어 커맨드 메뉴에서 실...
# 4  AI기능을 지원하는 갤럭시 기기에 적용된 노트 어시스트는 자동으로 노트의 서식을 정...
#
#                          분류     조회수
# 0  ['스스로해결', '모바일', '스마트폰']  612970
# 1  ['스스로해결', '모바일', '스마트폰']  103840
# 2  ['스스로해결', '모바일', '스마트폰']  156995
# 3  ['스스로해결', '모바일', '스마트폰']   96035
# 4  ['스스로해결', '모바일', '스마트폰']   99718
